# %%
# !pip install langchain_community
# !pip install replicate

# %%
from langchain_community.llms import Replicate
from google.colab import userdata
import os

# Ambil api token dari colab
api_token = userdata.get("api_token")

# Masukin token ke envor variable
os.environ["REPLICATE_API_TOKEN"] = api_token

# %%
parameters = {
  "top_k": 5,
  "top_p": 1.0,
  "max_tokens": 4096,
  "min_tokens": 0,
  "random_seed": None,
  "repetition_penalty": 1.0,
  "temperature": 0.7,
  "stopping_criteria": "length (256 tokens)",
  "stopping_sequence": None
}

llm = Replicate(
  model="ibm-granite/granite-3.3-8b-instruct",
  input=parameters,
)
# Out:
# WARNING:langchain_community.llms.replicate:Init param `input` is deprecated, please use `model_kwargs` instead.

# %%
output = llm.invoke("do you give me about script free for trading view"
)
print(output)
# Out:
# I'm afraid I can't provide direct scripts for TradingView, but I can guide you on how to create your own or point you to resources where you can find free scripts. TradingView has a public library of user-generated scripts and indicators, many of which are free to use. Here's how to find them:
#
# 1. Go to TradingView's official website and log in to your account.
# 2. Click on the "Charts" tab and select any asset you want.
# 3. Click on the "Indicators" button (looks like a paint palette) in the top menu.
# 4. In the search bar, type the keyword for the script or indicator you're looking for. For example, "Moving Average Crossover," "RSI," or any other popular indicators.
# 5. Browse through the list of results and click on the script to view its details, including its code.
#
# ...

# %%
# !pip install pandas
# !pip install -U langchain langchain-community langchain-experimental replicate

# %%
import pandas as pd
df = pd.read_csv("WBD.zip")
df
# Out:
#      country_name country_id  year  Inflation (CPI %)  GDP (Current USD)  \
# 0           Aruba         aw  2010           2.078141       2.453597e+09
# 1           Aruba         aw  2011           4.316297       2.637859e+09
# 2           Aruba         aw  2012           0.627472       2.615208e+09
# 3           Aruba         aw  2013          -2.372065       2.727850e+09
# 4           Aruba         aw  2014           0.421441       2.790850e+09
# ...           ...        ...   ...                ...                ...
# 3467     Zimbabwe         zw  2021          98.546105       2.724052e+10
# 3468     Zimbabwe         zw  2022         104.705171       3.278975e+10
# 3469     Zimbabwe         zw  2023                NaN       3.523137e+10
# 3470     Zimbabwe         zw  2024                NaN                NaN
# 3471     Zimbabwe         zw  2025                NaN                NaN
#
#       GDP per Capita (Current USD)  Unemployment Rate (%)  \
# ...

# %%
from langchain_experimental.agents.agent_toolkits.pandas.base import (
    create_pandas_dataframe_agent
)
import pandas as pd

agent = create_pandas_dataframe_agent(
    llm=llm,
    df=df,
    verbose=True,
    allow_dangerous_code=True,  # opt-in for Python REPL execution
)

# %%
    print(df.info())
    print(df.isnull().sum())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3472 entries, 0 to 3471
# Data columns (total 16 columns):
#  #   Column                           Non-Null Count  Dtype
# ---  ------                           --------------  -----
#  0   country_name                     3472 non-null   object
#  1   country_id                       3472 non-null   object
#  2   year                             3472 non-null   int64
#  3   Inflation (CPI %)                2694 non-null   float64
#  4   GDP (Current USD)                2933 non-null   float64
#  5   GDP per Capita (Current USD)     2938 non-null   float64
#  6   Unemployment Rate (%)            2795 non-null   float64
#  7   Interest Rate (Real, %)          1735 non-null   float64
#  8   Inflation (GDP Deflator, %)      2904 non-null   float64
#  9   GDP Growth (% Annual)            2912 non-null   float64
#  10  Current Account Balance (% GDP)  2563 non-null   float64
# ...

# %%
    # List of columns that are expected to be numeric but might have non-numeric characters
    numeric_cols = [
        'Inflation (CPI %)', 'GDP (Current USD)', 'GDP per Capita (Current USD)',
        'Unemployment Rate (%)', 'Interest Rate (Real, %)', 'Inflation (GDP Deflator, %)',
        'GDP Growth (% Annual)', 'Current Account Balance (% GDP)',
        'Government Expense (% of GDP)', 'Government Revenue (% of GDP)',
        'Tax Revenue (% of GDP)', 'Gross National Income (USD)', 'Public Debt (% of GDP)'
    ]

    for col in numeric_cols:
        if col in df.columns:
            # Remove dots and then convert to numeric.
            # If commas are used as decimal separators, replace them with dots first.
            # Based on the sample, it looks like dots are thousands separators.
            df[col] = df[col].astype(str).str.replace('.', '', regex=False)
            # If there are actual decimal commas, uncomment the next line:
            # df[col] = df[col].astype(str).str.replace(',', '.', regex=False)
            df[col] = pd.to_numeric(df[col], errors='coerce')

    # Convert 'year' to integer
    df['year'] = pd.to_numeric(df['year'], errors='coerce').astype('Int64')

    # Drop rows where 'year' is NaN after conversion (e.g., future years with no data)
    df.dropna(subset=['year'], inplace=True)
    df['year'] = df['year'].astype(int)

    # Handle remaining missing numeric values (e.g., fill with median or mean, or drop)
    # For simplicity, let's fill with the median for each column
    for col in numeric_cols:
        if col in df.columns:
            if df[col].isnull().any():
                median_val = df[col].median()
                df[col].fillna(median_val, inplace=True)

    print("\nDataFrame after cleaning numeric columns:")
    print(df.head())
    print(df.info())
# Out:
# DataFrame after cleaning numeric columns:
#   country_name country_id  year  Inflation (CPI %)  GDP (Current USD)  \
# 0        Aruba         aw  2010       2.078141e+14       2.453597e+14
# 1        Aruba         aw  2011       4.316297e+14       2.637859e+14
# 2        Aruba         aw  2012       6.274720e+14       2.615208e+14
# 3        Aruba         aw  2013      -2.372065e+14       2.727850e+14
# 4        Aruba         aw  2014       4.214409e+14       2.790850e+14
#
#    GDP per Capita (Current USD)  Unemployment Rate (%)  \
# 0                  2.409314e+14                 4961.0
# 1                  2.571238e+14                 4961.0
# 2                  2.511967e+14                 4961.0
# 3                  2.581358e+14                 4961.0
# 4                  2.612984e+14                 4961.0
#
#    Interest Rate (Real, %)  Inflation (GDP Deflator, %)  \
# 0             1.166613e+14                -1.223407e+14
# ...

# %%
    # Example: Create a GDP Growth Category
    def gdp_growth_category(growth):
        if growth > 5:
            return 'High Growth'
        elif growth > 0:
            return 'Moderate Growth'
        elif growth < -2:
            return 'Significant Contraction'
        elif growth < 0:
            return 'Slight Contraction'
        else:
            return 'Stagnant'

    df['GDP_Growth_Category'] = df['GDP Growth (% Annual)'].apply(gdp_growth_category)
    print("\nDataFrame with new feature:")
    print(df[['GDP Growth (% Annual)', 'GDP_Growth_Category']].head())
# Out:
# DataFrame with new feature:
#    GDP Growth (% Annual)      GDP_Growth_Category
# 0          -2.733457e+14  Significant Contraction
# 1           3.369237e+14              High Growth
# 2          -1.040800e+14  Significant Contraction
# 3           6.431483e+14              High Growth
# 4          -1.586575e+14  Significant Contraction

# %%
    # Example: Prepare data for classification
    # Let's say we want to classify countries based on their average economic performance
    # We might average indicators over the years for each country
    df_avg = df.groupby('country_name')[numeric_cols].mean().reset_index()

    # Define a target variable for classification (e.g., 'Economic_Stability_Class')
    # This would require a rule-based or pre-defined classification based on your analysis.
    # For a real classification task, you'd need a labeled dataset or a clear rule.
    # For demonstration, let's create a simple rule for 'Inflation_Category'
    def classify_inflation(cpi_avg):
        if cpi_avg > 10:
            return 'High Inflation'
        elif cpi_avg > 3:
            return 'Moderate Inflation'
        else:
            return 'Low Inflation'

    df_avg['Inflation_Category'] = df_avg['Inflation (CPI %)'].apply(classify_inflation)

    # Select features for IBM Granite
    features_for_granite = [
        'GDP Growth (% Annual)', 'Unemployment Rate (%)', 'Public Debt (% of GDP)',
        'Current Account Balance (% GDP)', 'Inflation (CPI %)'
    ]
    target_for_granite = 'Inflation_Category'

    df_granite_input = df_avg[['country_name'] + features_for_granite + [target_for_granite]]
    df_granite_input.to_csv('granite_input_data.csv', index=False)
    files.download('granite_input_data.csv') # Download to your local machine
